# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set(style = 'darkgrid')

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill',y='tip',data = tips)

# %%
sns.relplot(x='total_bill',y='tip',data = tips,hue='smoker',style='time')

# %%
sns.relplot(x='total_bill',y='tip',data = tips,hue='smoker',style='time',size='size')

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', 
            data = fmri, ci = 'sd')

# %%
sns.relplot(x = 'timepoint', y = 'signal', estimator = None,
            kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'event',
            kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', 
            style = 'event', kind = 'line', data = fmri)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', 
            col = 'time', data = tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker',
            col = 'size', data = tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'size',
            data = tips, col_wrap=3, height=3)

# %%
iris = sns.load_dataset('iris')

# %%
sns.scatterplot(x = 'sepal_length', y = 'petal_length', data = iris)

# %% [markdown]
# # categorical plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips)

# %%
sns.catplot(x = 'smoker', y = 'tip', data = tips, order= ['No', 'Yes'])

# %%
sns.catplot(x = 'day', y = 'tip', kind = 'box', data = tips, hue = 'sex')

# %%
sns.catplot(x = 'day', y = 'total_bill', kind = 'box', 
            data = tips, hue = 'sex', dodge = False)

# %%
diamonds = sns.load_dataset('diamonds')
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x = 'color', y = 'price', kind = 'boxen', 
            data = diamonds.sort_values('color'))

# %%
sns.catplot(x = 'total_bill', y = 'day', hue = 'sex', 
            kind = 'violin', data = tips, split = True,)

# %%
g = sns.catplot(x = 'day', y = 'total_bill', kind = 'violin', 
                inner = None, data = tips)
sns.swarmplot(x = 'day', y = 'total_bill', color = 'k', 
              size = 3, data = tips, ax = g.ax)

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x='deck',kind='count',data = titanic,hue='class',palette = 'ch:0.95')

# %%
from numpy.random import randn

# %%
x=randn(100)

# %%
x
# Out:
# array([-7.84161252e-01,  1.07937178e+00,  1.58757487e-01,  3.73396248e-01,
#        -5.61256145e-01,  3.19832754e-01, -8.38859965e-02,  8.67733085e-01,
#         2.52616241e+00,  1.12875301e+00, -2.57553701e+00,  1.20585219e+00,
#        -1.16918019e+00, -4.72437049e-02,  9.12452000e-01, -1.81727023e+00,
#        -9.83210216e-01, -9.36969868e-01, -6.82484191e-01,  5.07596633e-01,
#        -1.15269006e-01,  1.41478783e+00, -1.26967961e+00,  1.61678871e+00,
#        -2.16529208e+00,  6.74466129e-01,  1.44357008e+00, -1.13377463e+00,
#        -3.27477877e-01, -3.52096388e-01, -2.92350503e-01, -1.28508652e+00,
#        -9.42928353e-02,  1.51270769e+00, -2.88836404e-02,  1.45703864e+00,
#         1.39259811e-01, -5.36749071e-01, -3.74834510e-01,  2.78282606e-01,
#        -2.31275422e-01, -1.47668541e+00,  5.57496980e-03, -3.53865734e-01,
#        -6.16819003e-01, -2.56594355e-01,  1.33564444e+00, -7.81880719e-01,
#         1.70753518e-01,  5.96158515e-02,  9.04117246e-01, -5.25493745e-01,
#        -1.85675734e+00, -1.32183950e+00,  1.71323476e+00,  5.10374180e-01,
#         1.14578919e-01, -8.65392124e-01,  1.24950499e+00,  1.91816534e+00,
#        -4.95297936e-02,  1.31307483e+00,  2.94223875e-04,  5.51964562e-01,
#        -1.04025043e+00, -4.81224325e-01, -4.78980095e-01, -1.08689157e+00,
#         1.38975667e+00,  8.55973849e-02,  5.19840698e-01,  5.20129835e-01,
#         4.84412096e-01, -1.32594544e+00, -1.55510000e+00, -3.10620838e-01,
#         9.74298696e-01, -9.76226223e-01, -1.15978359e-01, -6.51237464e-02,
#        -2.90624839e-01,  1.07640184e+00,  4.88740239e-01, -1.24709115e+00,
#         1.00405743e-01, -4.17144738e-01,  1.08308711e+00,  1.32530202e+00,
#         5.40101722e-01, -5.54803391e-01,  1.80636960e+00, -1.48043299e+00,
#        -5.26682736e-01,  2.10778795e-03, -7.67390843e-01, -1.56485123e+00,
#         4.77724192e-01,  6.15872063e-02, -4.97761298e-01, -9.61714885e-01])

# %%
sns.distplot(x,hist=True,bins=30)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
x = tips['total_bill']
y = tips['tip']

# %%
sns.jointplot(x = x, y=y)

# %%
sns.set()
sns.jointplot(x = x, y=y, kind = 'hex')

# %%
iris = sns.load_dataset('iris')

# %%
sns.pairplot(iris)

# %%
sns.lmplot(x = 'total_bill', y= 'tip', data = tips)

# %%
def sinplot():
    x = np.linspace(0, 14, 100)
    for i in range(1,5):
        plt.plot(x, np.sin(x))

# %%
sinplot()
